# %%
import pandas as pd
import matplotlib.pyplot as plt
df_activities = pd.read_csv("cardio.csv")

# %%
# creating subset
#subset_data = discoveries['1950-01-01':'1960-01-01']
runs_subset_2013_2018 = df_activities.loc["20190101":"20130101"]  #subsetting from 2013 to 2018

# %%
runs_subset_2013_2018.plot(subplots=True, sharex=False, figsize=(12,16), marker="o", markersize=3)
plt.show()

# %% [markdown]
# Presence of Nan values in the rows in the df_activities
